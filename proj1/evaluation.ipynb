# %%
from dlc_practical_prologue import *
import projet1_helpers as helpers
import models.MLP as MLP_aux
import models.deep_MLP as deep_MLP_aux
import models.CNN_WS_Aux as CNN_aux
import models.CNN_WS as CNN_WS
import models.number_classifier as nc
import models.pretrain_learning as pl
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
MLP_aux.eval(10, mb_size=100, lr=0.1, epochs=25, aux_loss=True, verbose=False)
# Out:
# The accuracy of the model is 0.7651 ± 0.0055

# %%
deep_MLP_aux.eval(10, mb_size=100, lr=0.5, epochs=25, verbose=False)
# Out:
# The accuracy of the model is 0.7345 ± 0.0126

# %%
CNN_aux.eval(10, mb_size=100, lr=0.1, epochs=25, aux_loss=True, verbose=False)
# Out:
# The accuracy of the model is 0.7973 ± 0.0010

# %%
CNN_WS.eval(10)
# Out:
# The accuracy of the model is 0.8308 ± 0.0006

# %%
nc.eval(10)
# Out:
# The accuracy of the model is 0.9707 ± 0.0001

# %%
pl.eval(10)
# Out:
# The accuracy of the model is 0.9008 ± 0.0000

# %%
# Generate the pairs
train_input, train_target, train_classes, test_input, test_target, test_classes = helpers.load_data(1000)

# define the model
model = CNN_WS.CNNrws()

# train model
CNN_WS.train(model, train_input, train_target, train_classes, 35, 100, 0.01, True)
print(f"Baseline Training accuracy is {CNN_WS.accuracy(model, train_input, train_target)} ")
test_accuracy = CNN_WS.accuracy(model, test_input, test_target)
print(f"Baseline Test accuracy is {test_accuracy} ")
# Out:
# 0 7.054186642169952
# 1 6.90472275018692
# 2 6.89858740568161
# 3 6.89778333902359
# 4 6.897111892700195
# 5 6.897378325462341
# 6 6.896749436855316
# 7 6.896897554397583
# 8 6.898226797580719
# 9 6.894384980201721
# 10 6.705111265182495
# 11 6.130308985710144
# 12 5.710270941257477
# 13 4.905568212270737
# 14 4.365105837583542
# 15 4.434364199638367
# 16 4.3167281448841095
# 17 4.244661867618561
# 18 4.140794098377228
# 19 4.389754056930542
# 20 4.100731432437897
# 21 3.8319495916366577
# 22 3.777364104986191
# 23 3.8679065704345703
# 24 3.911413222551346
# 25 3.9733037650585175
# 26 3.694876790046692
# 27 3.6630061268806458
# 28 3.5423948168754578
# 29 3.377542734146118
# 30 3.489157736301422
# 31 3.486501097679138
# 32 3.3888142704963684
# 33 3.354760855436325
# 34 3.3076439201831818
# Baseline Training accuracy is 0.862
# Baseline Test accuracy is 0.834
